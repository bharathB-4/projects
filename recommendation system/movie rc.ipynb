# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fm=pd.read_csv(r"C:\Users\bharath\Downloads\movies_metadata.csv",low_memory=False)
fm.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
fm.shape
# Out:
# (45466, 24)

# %%
fm.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
#univariate analysis
fm["vote_average"].hist(bins=10)

# %%
sns.boxplot(fm["vote_average"])

# %%
fm["vote_count"].hist(bins=20)

# %%
c=fm["vote_average"].mean()
c
# Out:
# 5.618207215133889

# %%
m=fm["vote_count"].quantile(0.8)
m
# Out:
# 50.0

# %%
rc=fm[(fm["runtime"]>140) & (fm["revenue"]>310000000) & (fm["homepage"]).notna()]
rc.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False                                                NaN   22000000
# 1639  False                                                NaN  200000000
# 4766  False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863  False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5244  False  {'id': 10, 'name': 'Star Wars Collection', 'po...  120000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4766  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5244  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                homepage    id    imdb_id  \
# 522                      http://www.schindlerslist.com/   424  tt0108052
# ...

# %%
rc.shape
# Out:
# (52, 24)

# %%
rc["vote_count"]>=m
# Out:
# 522      True
# 1639     True
# 4766     True
# 4863     True
# 5244     True
# 5814     True
# 5851     True
# 6390     True
# 7000     True
# 10554    True
# 10972    True
# 11008    True
# 11067    True
# 11404    True
# 11827    True
# 11925    True
# 12481    True
# 12641    True
# 13219    True
# 13605    True
# 13833    True
# 13893    True
# 14416    True
# 14551    True
# 15480    True
# 16128    True
# 17293    True
# 17818    True
# 18244    True
# 18252    True
# 19261    True
# 19971    True
# 20051    True
# 20062    True
# 21068    True
# 22058    True
# 22059    True
# 22131    True
# 22879    True
# 23187    True
# 23617    True
# 23675    True
# 25390    True
# 26558    True
# 26567    True
# 26569    True
# 30051    True
# 30761    True
# 31072    True
# 31865    True
# 33356    True
# 44842    True
# Name: vote_count, dtype: bool

# %%
rc=rc[rc["vote_count"]>=m]
rc.shape
# Out:
# (52, 24)

# %%
#imdb rating calculation
def wr(x,m=m,c=c):
    v=x["vote_count"]
    r=x["vote_average"]
    return (v/(v+m)*r)+(m/(m/(m+v)*c))

# %%
#gives score
rc["score"]=rc.apply(wr,axis=1)
rc.head()
# Out:
#       adult                              belongs_to_collection     budget  \
# 522   False                                                NaN   22000000
# 1639  False                                                NaN  200000000
# 4766  False  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000
# 4863  False  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000
# 5244  False  {'id': 10, 'name': 'Star Wars Collection', 'po...  120000000
#
#                                                  genres  \
# 522   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 1639  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4766  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 4863  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 5244  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                homepage    id    imdb_id  \
# 522                      http://www.schindlerslist.com/   424  tt0108052
# ...

# %%
rc=rc.sort_values("score",ascending=False)

# %%
#sorting based on score
rc[["title","vote_count","vote_average","score"]].head()
# Out:
#                  title  vote_count  vote_average        score
# 15480        Inception     14075.0           8.1  2522.218538
# 12481  The Dark Knight     12269.0           8.3  2200.958666
# 14551           Avatar     12114.0           7.2  2172.273886
# 17818     The Avengers     12000.0           7.4  2152.181605
# 22879     Interstellar     11187.0           8.1  2008.168186

# %%
#creating visualization
d=fm.sort_values("vote_count",ascending=False)
plt.figure(figsize=(8,16))
plt.barh(d["title"].head(15),d["vote_count"].head(15),align='center',color='red')
plt.gca().invert_yaxis()
plt.xlabel("votes")
plt.title("must voted movies")
# Out:
# Text(0.5, 1.0, 'must voted movies')
